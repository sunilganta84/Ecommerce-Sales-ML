# %% [markdown]
# <a href="https://colab.research.google.com/github/sunilganta84/Ecommerce-Sales-ML/blob/main/GANNLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 3.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16 xxhash-3.4.1

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.layers import Dense, Embedding, LSTM
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings("ignore")

# Error handling with try-catch
try:
    # Load the conv_ai_3 dataset
    ds = tfds.load('huggingface:conv_ai_3/conv_ai_3', split='train')

    # Preprocess the text data
    tokenizer = tfds.deprecated.text.Tokenizer()
    vocabulary_set = set()

    for example in ds:
        text = example['question'].numpy().decode('utf-8')  # Access the question text
        tokens = tokenizer.tokenize(text)
        vocabulary_set.update(tokens)

    encoder = tfds.deprecated.text.TokenTextEncoder(list(vocabulary_set))  # Convert vocabulary_set to list

    # Define the Generator model
    class Generator(tf.keras.Model):
        def __init__(self, vocab_size, embedding_dim, rnn_units):
            super(Generator, self).__init__()
            self.embedding = Embedding(vocab_size, embedding_dim)
            self.lstm = LSTM(rnn_units, return_sequences=True, return_state=True)
            self.dense = Dense(vocab_size, activation='softmax')

        def call(self, x, hidden):
            x = self.embedding(x)
            x, state_h, state_c = self.lstm(x, initial_state=hidden)
            x = self.dense(x)
            return x[:, -1, :], [state_h, state_c]

    # Define the Discriminator model
    class Discriminator(tf.keras.Model):
        def __init__(self):
            super(Discriminator, self).__init__()
            self.dense = Dense(64, activation='relu')

        def call(self, x):
            x = tf.reshape(x, [-1, x.shape[1], 1])
            x = self.dense(x)
            return x

    # Define the loss function and optimizer
    loss_object = BinaryCrossentropy(from_logits=True)
    generator_optimizer = Adam(learning_rate=0.001)
    discriminator_optimizer = Adam(learning_rate=0.001)

    # Define the loss function for the Generator
    def generator_loss(fake_output):
        return loss_object(tf.ones_like(fake_output), fake_output)

    # Define the loss function for the Discriminator
    def discriminator_loss(real_output, fake_output):
        real_loss = loss_object(tf.ones_like(real_output), real_output)
        fake_loss = loss_object(tf.zeros_like(fake_output), fake_output)
        total_loss = real_loss + fake_loss
        return total_loss

    # Define the training step
    @tf.function
    def train_step(real_text):
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            initial_state = [tf.zeros((1, rnn_units)), tf.zeros((1, rnn_units))]

            generated_text, _ = generator(real_text, initial_state)
            real_output = discriminator(real_text)
            fake_output = discriminator(generated_text)

            gen_loss = generator_loss(fake_output)
            disc_loss = discriminator_loss(real_output, fake_output)

        gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
        gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

        generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
        discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))
        return gen_loss, disc_loss

    # Define hyperparameters
    embedding_dim = 256
    rnn_units = 1024
    vocab_size = len(vocabulary_set)

    # Initialize the Generator and Discriminator models
    generator = Generator(vocab_size, embedding_dim, rnn_units)
    discriminator = Discriminator()

    # Train the GAN model
    EPOCHS = 10
    for epoch in range(EPOCHS):
        for example in ds:
            text = example['question'].numpy().decode('utf-8')  # Access the question text
            tokens = tokenizer.tokenize(text)
            filtered_tokens = [token for token in tokens if token in vocabulary_set]
            if filtered_tokens:
                print("Filtered Tokens:", filtered_tokens)  # Debugging statement
                encoded_text = encoder.encode(' '.join(filtered_tokens))  # Join tokens into a single string
                real_text = tf.expand_dims(encoded_text, 0)
                real_text = pad_sequences(real_text, padding='post')  # Pad the input sequences

                try:
                    gen_loss, disc_loss = train_step(real_text)
                except tf.errors.InvalidArgumentError as error:
                    print("InvalidArgumentError:", error)
                    # Handle error gracefully, e.g., by logging and continuing training or by terminating
                    # showErrorMessage(error)

        print(f'Epoch {epoch+1}, Generator Loss: {gen_loss}, Discriminator Loss: {disc_loss}')

except Exception as error:
    # log error
    print(error)
    # handle error
    showErrorMessage(error)
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/conv_ai_3/conv_ai_3/1.0.0...
# Downloading data:   0%|          | 0.00/321k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/85.9k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9176 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2313 [00:00<?, ? examples/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/conv_ai_3/conv_ai_3/1.0.0.incompleteZ51DLK/conv_ai_3-train.tfrecord*...:  …
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/conv_ai_3/conv_ai_3/1.0.0.incompleteZ51DLK/conv_ai_3-validation.tfrecord*.…
# Dataset conv_ai_3 downloaded and prepared to /root/tensorflow_datasets/conv_ai_3/conv_ai_3/1.0.0. Subsequent calls will reuse this data.
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'seeing', 'barack', 'obamas', 'family']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'barack', 'obamas', 'geneology']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'about', 'obamas', 'ancestors']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'who', 'is', 'currently', 'alive', 'from', 'president', 'obamas', 'family', 'tree']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'biological', 'information', 'on', 'his', 'family']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'the', 'time', 'magazine', 'essay']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'obamas', 'parents']
# Filtered Tokens: ['how', 'many', 'generations', 'would', 'you', 'like', 'me', 'to', 'list', 'from', 'president', 'obamas', 'family', 'tree']
# Filtered Tokens: ['what', 'would', 'you', 'like', 'to', 'know', 'about', 'obamas', 'heritage']
# Filtered Tokens: ['which', 'family', 'members', 'of', 'obama', 'are', 'you', 'interested', 'in', 'learning', 'more', 'about']
# Filtered Tokens: ['which', 'specific', 'details', 'would', 'you', 'like', 'to', 'learn', 'about', 'obamas', 'heritage']
# WARNING:tensorflow:5 out of the last 11 calls to <function train_step at 0x7c87a1456320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Filtered Tokens: ['would', 'you', 'like', 'to', 'hear', 'about', 'president', 'obamas', 'family', 'tree']
# WARNING:tensorflow:6 out of the last 12 calls to <function train_step at 0x7c87a1456320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Streaming output truncated to the last 5000 lines.
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "<ipython-input-3-e62939be33b7>", line 110, in <cell line: 11>
#
#   File "<ipython-input-3-e62939be33b7>", line 73, in train_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "<ipython-input-3-e62939be33b7>", line 35, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py", line 272, in call
#
# indices[0,6] = 2382 is not in [0, 2382)
# 	 [[{{node generator/embedding/embedding_lookup}}]] [Op:__inference_train_step_98332]
# Filtered Tokens: ['would', 'you', 'like', 'to', 'buy', 'some', 'stuff', 'related', 'pittsburgh', 'penguins']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'the', 'penguins', 'schedule']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'see', 'penguins', 'of', 'madagascar']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'a', 'specific', 'type', 'of', 'penguin']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'animal', 'or', 'the', 'hockey', 'team']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'penguins', 'of', 'madagascar']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'where', 'penguins', 'live']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'specific', 'web', 'page']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'any', 'specific', 'information', 'about', 'the', 'birds']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'some', 'photos']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'the', 'move']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'penguin', 'vape']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'hear', 'pittsburgh', 'penguin', 'news']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'hear', 'about', 'the', 'pittsburgh', 'penguins']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'watch', 'funny', 'penguin', 'videos']
# Filtered Tokens: ['what', 'kind', 'of', 'penguin', 'are', 'you', 'looking', 'for']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'buy', 'a', 'book', 'about', 'this', 'topic']
# InvalidArgumentError: Graph execution error:
#
# Detected at node generator/embedding/embedding_lookup defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "<ipython-input-3-e62939be33b7>", line 110, in <cell line: 11>
#
#   File "<ipython-input-3-e62939be33b7>", line 73, in train_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "<ipython-input-3-e62939be33b7>", line 35, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py", line 272, in call
#
# indices[0,6] = 2382 is not in [0, 2382)
# 	 [[{{node generator/embedding/embedding_lookup}}]] [Op:__inference_train_step_98332]
# Filtered Tokens: ['would', 'you', 'like', 'to', 'buy', 'some', 'stuff', 'related', 'pittsburgh', 'penguins']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'the', 'penguins', 'schedule']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'see', 'penguins', 'of', 'madagascar']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'a', 'specific', 'type', 'of', 'penguin']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'animal', 'or', 'the', 'hockey', 'team']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'penguins', 'of', 'madagascar']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'where', 'penguins', 'live']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'specific', 'web', 'page']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'any', 'specific', 'information', 'about', 'the', 'birds']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'some', 'photos']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'the', 'move']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'penguin', 'vape']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'hear', 'pittsburgh', 'penguin', 'news']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'hear', 'about', 'the', 'pittsburgh', 'penguins']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'watch', 'funny', 'penguin', 'videos']
# Filtered Tokens: ['what', 'kind', 'of', 'penguin', 'are', 'you', 'looking', 'for']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'buy', 'a', 'book', 'about', 'this', 'topic']
# InvalidArgumentError: Graph execution error:
#
# Detected at node generator/embedding/embedding_lookup defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "<ipython-input-3-e62939be33b7>", line 110, in <cell line: 11>
#
#   File "<ipython-input-3-e62939be33b7>", line 73, in train_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "<ipython-input-3-e62939be33b7>", line 35, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py", line 272, in call
#
# indices[0,6] = 2382 is not in [0, 2382)
# 	 [[{{node generator/embedding/embedding_lookup}}]] [Op:__inference_train_step_98332]
# Filtered Tokens: ['would', 'you', 'like', 'to', 'buy', 'some', 'stuff', 'related', 'pittsburgh', 'penguins']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'the', 'penguins', 'schedule']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'see', 'penguins', 'of', 'madagascar']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'a', 'specific', 'type', 'of', 'penguin']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'animal', 'or', 'the', 'hockey', 'team']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'penguins', 'of', 'madagascar']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'where', 'penguins', 'live']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'specific', 'web', 'page']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'any', 'specific', 'information', 'about', 'the', 'birds']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'some', 'photos']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'the', 'move']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'penguin', 'vape']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'hear', 'pittsburgh', 'penguin', 'news']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'hear', 'about', 'the', 'pittsburgh', 'penguins']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'watch', 'funny', 'penguin', 'videos']
# Filtered Tokens: ['what', 'kind', 'of', 'penguin', 'are', 'you', 'looking', 'for']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'buy', 'a', 'book', 'about', 'this', 'topic']
# InvalidArgumentError: Graph execution error:
#
# Detected at node generator/embedding/embedding_lookup defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "<ipython-input-3-e62939be33b7>", line 110, in <cell line: 11>
#
#   File "<ipython-input-3-e62939be33b7>", line 73, in train_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "<ipython-input-3-e62939be33b7>", line 35, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py", line 272, in call
#
# indices[0,6] = 2382 is not in [0, 2382)
# 	 [[{{node generator/embedding/embedding_lookup}}]] [Op:__inference_train_step_98332]
# Filtered Tokens: ['would', 'you', 'like', 'to', 'buy', 'some', 'stuff', 'related', 'pittsburgh', 'penguins']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'the', 'penguins', 'schedule']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'see', 'penguins', 'of', 'madagascar']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'a', 'specific', 'type', 'of', 'penguin']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'animal', 'or', 'the', 'hockey', 'team']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'penguins', 'of', 'madagascar']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'where', 'penguins', 'live']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'specific', 'web', 'page']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'any', 'specific', 'information', 'about', 'the', 'birds']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'some', 'photos']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'the', 'move']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'penguin', 'vape']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'hear', 'pittsburgh', 'penguin', 'news']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'hear', 'about', 'the', 'pittsburgh', 'penguins']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'watch', 'funny', 'penguin', 'videos']
# Filtered Tokens: ['what', 'kind', 'of', 'penguin', 'are', 'you', 'looking', 'for']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'buy', 'a', 'book', 'about', 'this', 'topic']
# InvalidArgumentError: Graph execution error:
#
# Detected at node generator/embedding/embedding_lookup defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "<ipython-input-3-e62939be33b7>", line 110, in <cell line: 11>
#
#   File "<ipython-input-3-e62939be33b7>", line 73, in train_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "<ipython-input-3-e62939be33b7>", line 35, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py", line 272, in call
#
# indices[0,6] = 2382 is not in [0, 2382)
# 	 [[{{node generator/embedding/embedding_lookup}}]] [Op:__inference_train_step_98332]
# Filtered Tokens: ['would', 'you', 'like', 'to', 'buy', 'some', 'stuff', 'related', 'pittsburgh', 'penguins']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'the', 'penguins', 'schedule']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'see', 'penguins', 'of', 'madagascar']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'a', 'specific', 'type', 'of', 'penguin']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'animal', 'or', 'the', 'hockey', 'team']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'penguins', 'of', 'madagascar']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'where', 'penguins', 'live']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'specific', 'web', 'page']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'any', 'specific', 'information', 'about', 'the', 'birds']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'some', 'photos']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'the', 'move']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'costs', 'of', 'building', 'a', 'fence']
# Filtered Tokens: ['will', 'this', 'be', 'a', 'tall', 'fence', 'or', 'short', 'fence']
# Filtered Tokens: ['will', 'this', 'be', 'used', 'as', 'a', 'animal', 'pen']
# Filtered Tokens: ['are', 'you', 'keeping', 'people', 'out', 'or', 'animals', 'in']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'companies', 'to', 'build', 'a', 'fence', 'for', 'you']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'fencebuilding', 'materials']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'instructions', 'to', 'build', 'a', 'fence']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'places', 'to', 'buy', 'fencebuilding', 'materials']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'build', 'a', 'specific', 'kind', 'of', 'fence']
# Filtered Tokens: ['are', 'you', 'using', 'this', 'around', 'the', 'yard']
# Filtered Tokens: ['is', 'there', 'a', 'specific', 'material', 'it', 'needs', 'to', 'be', 'made', 'from', 'wood', 'cement', 'tin']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'costs', 'of', 'building', 'a', 'fence']
# Filtered Tokens: ['will', 'this', 'be', 'a', 'tall', 'fence', 'or', 'short', 'fence']
# Filtered Tokens: ['will', 'this', 'be', 'used', 'as', 'a', 'animal', 'pen']
# Filtered Tokens: ['are', 'you', 'keeping', 'people', 'out', 'or', 'animals', 'in']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'companies', 'to', 'build', 'a', 'fence', 'for', 'you']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'fencebuilding', 'materials']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'instructions', 'to', 'build', 'a', 'fence']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'places', 'to', 'buy', 'fencebuilding', 'materials']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'build', 'a', 'specific', 'kind', 'of', 'fence']
# Filtered Tokens: ['are', 'you', 'using', 'this', 'around', 'the', 'yard']
# Filtered Tokens: ['is', 'there', 'a', 'specific', 'material', 'it', 'needs', 'to', 'be', 'made', 'from', 'wood', 'cement', 'tin']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'costs', 'of', 'building', 'a', 'fence']
# Filtered Tokens: ['will', 'this', 'be', 'a', 'tall', 'fence', 'or', 'short', 'fence']
# Filtered Tokens: ['will', 'this', 'be', 'used', 'as', 'a', 'animal', 'pen']
# Filtered Tokens: ['are', 'you', 'keeping', 'people', 'out', 'or', 'animals', 'in']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'companies', 'to', 'build', 'a', 'fence', 'for', 'you']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'fencebuilding', 'materials']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'instructions', 'to', 'build', 'a', 'fence']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'places', 'to', 'buy', 'fencebuilding', 'materials']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'build', 'a', 'specific', 'kind', 'of', 'fence']
# Filtered Tokens: ['are', 'you', 'using', 'this', 'around', 'the', 'yard']
# Filtered Tokens: ['is', 'there', 'a', 'specific', 'material', 'it', 'needs', 'to', 'be', 'made', 'from', 'wood', 'cement', 'tin']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'costs', 'of', 'building', 'a', 'fence']
# Filtered Tokens: ['will', 'this', 'be', 'a', 'tall', 'fence', 'or', 'short', 'fence']
# Filtered Tokens: ['will', 'this', 'be', 'used', 'as', 'a', 'animal', 'pen']
# Filtered Tokens: ['are', 'you', 'keeping', 'people', 'out', 'or', 'animals', 'in']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'companies', 'to', 'build', 'a', 'fence', 'for', 'you']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'fencebuilding', 'materials']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'instructions', 'to', 'build', 'a', 'fence']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'places', 'to', 'buy', 'fencebuilding', 'materials']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'build', 'a', 'specific', 'kind', 'of', 'fence']
# Filtered Tokens: ['are', 'you', 'using', 'this', 'around', 'the', 'yard']
# Filtered Tokens: ['is', 'there', 'a', 'specific', 'material', 'it', 'needs', 'to', 'be', 'made', 'from', 'wood', 'cement', 'tin']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'a', 'school', 'district']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'kennycaffey', 'syndorme']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'railroads']
# Filtered Tokens: ['what', 'entity', 'are', 'you', 'referring', 'to', 'with', 'this', 'acrocym']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'see', 'info', 'about', 'the', 'kansas', 'city', 'southern', 'railway']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'learning', 'more', 'about', 'knowledgecentered', 'service']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'korean', 'community', 'services']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'specific', 'energy', 'related', 'company']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'furniture']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'kcs', 'academy']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'knowledge', 'centered', 'support']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'find', 'out', 'about', 'the', 'kcs', 'mental', 'health', 'clinic']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'look', 'for', 'kucoin', 'shares', 'cryptocurrency']
# Filtered Tokens: ['are', 'you', 'looking', 'bellevue', 'square', 'mall']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'washington']
# Filtered Tokens: ['do', 'you', 'need', 'information', 'about', 'bellevue', 'nebraska']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'the', 'nearest', 'town', 'named', 'bellevue']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'companies', 'headquartered', 'in', 'bellevue', 'washington']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'the', 'bellevue', 'washington', 'local', 'government']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'see', 'notable', 'residents', 'of', 'bellevue', 'washington']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'bellevue', 'baptist', 'church']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'hospital', 'in', 'new', 'york', 'ny']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'directions', 'to', 'bellevue']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'college']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'university', 'the', 'bellevue']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'things', 'to', 'do', 'in', 'bellevue']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'iowa']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'nebraska']
# Filtered Tokens: ['are', 'you', 'looking', 'bellevue', 'square', 'mall']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'washington']
# Filtered Tokens: ['do', 'you', 'need', 'information', 'about', 'bellevue', 'nebraska']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'the', 'nearest', 'town', 'named', 'bellevue']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'companies', 'headquartered', 'in', 'bellevue', 'washington']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'the', 'bellevue', 'washington', 'local', 'government']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'see', 'notable', 'residents', 'of', 'bellevue', 'washington']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'bellevue', 'baptist', 'church']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'hospital', 'in', 'new', 'york', 'ny']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'directions', 'to', 'bellevue']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'college']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'university', 'the', 'bellevue']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'things', 'to', 'do', 'in', 'bellevue']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'iowa']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'nebraska']
# Filtered Tokens: ['are', 'you', 'looking', 'bellevue', 'square', 'mall']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'washington']
# Filtered Tokens: ['do', 'you', 'need', 'information', 'about', 'bellevue', 'nebraska']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'the', 'nearest', 'town', 'named', 'bellevue']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'companies', 'headquartered', 'in', 'bellevue', 'washington']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'the', 'bellevue', 'washington', 'local', 'government']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'see', 'notable', 'residents', 'of', 'bellevue', 'washington']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'bellevue', 'baptist', 'church']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'hospital', 'in', 'new', 'york', 'ny']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'directions', 'to', 'bellevue']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'college']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'university', 'the', 'bellevue']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'things', 'to', 'do', 'in', 'bellevue']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'iowa']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'nebraska']
# Filtered Tokens: ['are', 'you', 'looking', 'bellevue', 'square', 'mall']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'washington']
# Filtered Tokens: ['do', 'you', 'need', 'information', 'about', 'bellevue', 'nebraska']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'the', 'nearest', 'town', 'named', 'bellevue']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'companies', 'headquartered', 'in', 'bellevue', 'washington']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'the', 'bellevue', 'washington', 'local', 'government']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'see', 'notable', 'residents', 'of', 'bellevue', 'washington']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'bellevue', 'baptist', 'church']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'hospital', 'in', 'new', 'york', 'ny']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'directions', 'to', 'bellevue']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'college']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'university', 'the', 'bellevue']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'things', 'to', 'do', 'in', 'bellevue']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'iowa']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'nebraska']
# Filtered Tokens: ['are', 'you', 'looking', 'bellevue', 'square', 'mall']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'washington']
# Filtered Tokens: ['do', 'you', 'need', 'information', 'about', 'bellevue', 'nebraska']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'the', 'nearest', 'town', 'named', 'bellevue']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'companies', 'headquartered', 'in', 'bellevue', 'washington']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'the', 'bellevue', 'washington', 'local', 'government']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'see', 'notable', 'residents', 'of', 'bellevue', 'washington']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'bellevue', 'baptist', 'church']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'hospital', 'in', 'new', 'york', 'ny']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'directions', 'to', 'bellevue']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'college']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'university', 'the', 'bellevue']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'things', 'to', 'do', 'in', 'bellevue']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'iowa']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'nebraska']
# Filtered Tokens: ['are', 'you', 'looking', 'bellevue', 'square', 'mall']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'washington']
# Filtered Tokens: ['do', 'you', 'need', 'information', 'about', 'bellevue', 'nebraska']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'the', 'nearest', 'town', 'named', 'bellevue']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'companies', 'headquartered', 'in', 'bellevue', 'washington']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'the', 'bellevue', 'washington', 'local', 'government']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'see', 'notable', 'residents', 'of', 'bellevue', 'washington']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'bellevue', 'baptist', 'church']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'hospital', 'in', 'new', 'york', 'ny']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'directions', 'to', 'bellevue']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'college']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'university', 'the', 'bellevue']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'things', 'to', 'do', 'in', 'bellevue']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'iowa']
# Filtered Tokens: ['are', 'you', 'referring', 'to', 'bellevue', 'nebraska']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'knowing', 'more', 'about', 'a', 'computer', 'worm']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'facts', 'about', 'the', 'creature', 'worm']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'many', 'different', 'types', 'of', 'worms', 'there', 'are']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'where', 'worms', 'come', 'from']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'learn', 'where', 'to', 'purchase', 'fishing', 'bait']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'what', 'a', 'conficker', 'is']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'pictures', 'of', 'worms']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'computer', 'game', 'worms']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'information', 'about', 'computer', 'viruses']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'information', 'on', 'the', 'life', 'cycle', 'of', 'worms']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'find', 'out', 'what', 'worms', 'eat']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'find', 'out', 'about', 'the', 'animal', 'worm', 'or', 'a', 'why', 'a', 'person', 'is', 'called', 'a', 'worm']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'worm', 'castings']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'worms', 'in', 'dogs']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'knowing', 'more', 'about', 'a', 'computer', 'worm']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'facts', 'about', 'the', 'creature', 'worm']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'many', 'different', 'types', 'of', 'worms', 'there', 'are']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'where', 'worms', 'come', 'from']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'learn', 'where', 'to', 'purchase', 'fishing', 'bait']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'what', 'a', 'conficker', 'is']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'pictures', 'of', 'worms']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'computer', 'game', 'worms']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'information', 'about', 'computer', 'viruses']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'information', 'on', 'the', 'life', 'cycle', 'of', 'worms']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'find', 'out', 'what', 'worms', 'eat']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'find', 'out', 'about', 'the', 'animal', 'worm', 'or', 'a', 'why', 'a', 'person', 'is', 'called', 'a', 'worm']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'worm', 'castings']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'worms', 'in', 'dogs']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'knowing', 'more', 'about', 'a', 'computer', 'worm']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'facts', 'about', 'the', 'creature', 'worm']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'many', 'different', 'types', 'of', 'worms', 'there', 'are']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'where', 'worms', 'come', 'from']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'learn', 'where', 'to', 'purchase', 'fishing', 'bait']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'what', 'a', 'conficker', 'is']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'pictures', 'of', 'worms']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'the', 'computer', 'game', 'worms']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'information', 'about', 'computer', 'viruses']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'information', 'on', 'the', 'life', 'cycle', 'of', 'worms']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'find', 'out', 'what', 'worms', 'eat']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'find', 'out', 'about', 'the', 'animal', 'worm', 'or', 'a', 'why', 'a', 'person', 'is', 'called', 'a', 'worm']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'worm', 'castings']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'about', 'worms', 'in', 'dogs']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'ways', 'to', 'fix', 'problems', 'flushing', 'the', 'toilet']
# Filtered Tokens: ['which', 'battle', 'would', 'you', 'like', 'to', 'learn', 'about', 'how', 'the', 'technique', 'of', 'flushing', 'was', 'used']
# Filtered Tokens: ['would', 'you', 'like', 'directions', 'to', 'flushing', 'new', 'york']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'about', 'blushing']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'about', 'the', 'plumbing', 'mechanisms', 'of', 'flushing']
# ...
# Filtered Tokens: ['do', 'you', 'want', 'to', 'buy', 'it', 'online']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'learn', 'how', 'to', 'make', 'furniture']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'sell', 'furniture']
# Filtered Tokens: ['have', 'you', 'got', 'any', 'specific', 'question', 'regarding', 'furniture', 'size']
# Filtered Tokens: ['what', 'type', 'of', 'furniture', 'are', 'you', 'looking', 'for']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'bedroom', 'furniture']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'dining', 'room', 'furniture']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'furniture', 'for', 'a', 'specific', 'room']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'information', 'about', 'any', 'specific', 'decoration', 'technique']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'kitchen', 'furniture']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'living', 'room', 'furniture']
# Filtered Tokens: ['do', 'you', 'need', 'any', 'specific', 'tips', 'on', 'decoration']
# Filtered Tokens: ['do', 'you', 'need', 'information', 'about', 'furniture', 'arrangement']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'learning', 'how', 'to', 'play', 'poker']
# Filtered Tokens: ['would', 'you', 'like', 'a', 'schedule', 'of', 'poker', 'tournaments']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'world', 'series', 'of', 'poker']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'find', 'local', 'tournaments', 'near', 'you']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'poker', 'tournaments', 'are', 'played']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'who', 'won', 'the', 'last', 'world', 'series', 'of', 'poker']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'play', 'in', 'online', 'poker', 'tournaments']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'watch', 'a', 'tournament', 'online']
# Filtered Tokens: ['where', 'would', 'you', 'like', 'to', 'find', 'poker', 'tournaments']
# Filtered Tokens: ['which', 'poker', 'tournament', 'are', 'you', 'interested', 'in', 'knowing', 'more', 'about']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'learning', 'how', 'to', 'play', 'poker']
# Filtered Tokens: ['would', 'you', 'like', 'a', 'schedule', 'of', 'poker', 'tournaments']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'world', 'series', 'of', 'poker']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'find', 'local', 'tournaments', 'near', 'you']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'poker', 'tournaments', 'are', 'played']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'who', 'won', 'the', 'last', 'world', 'series', 'of', 'poker']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'play', 'in', 'online', 'poker', 'tournaments']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'watch', 'a', 'tournament', 'online']
# Filtered Tokens: ['where', 'would', 'you', 'like', 'to', 'find', 'poker', 'tournaments']
# Filtered Tokens: ['which', 'poker', 'tournament', 'are', 'you', 'interested', 'in', 'knowing', 'more', 'about']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'learning', 'how', 'to', 'play', 'poker']
# Filtered Tokens: ['would', 'you', 'like', 'a', 'schedule', 'of', 'poker', 'tournaments']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'world', 'series', 'of', 'poker']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'find', 'local', 'tournaments', 'near', 'you']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'poker', 'tournaments', 'are', 'played']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'who', 'won', 'the', 'last', 'world', 'series', 'of', 'poker']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'play', 'in', 'online', 'poker', 'tournaments']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'watch', 'a', 'tournament', 'online']
# Filtered Tokens: ['where', 'would', 'you', 'like', 'to', 'find', 'poker', 'tournaments']
# Filtered Tokens: ['which', 'poker', 'tournament', 'are', 'you', 'interested', 'in', 'knowing', 'more', 'about']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'learning', 'how', 'to', 'play', 'poker']
# Filtered Tokens: ['would', 'you', 'like', 'a', 'schedule', 'of', 'poker', 'tournaments']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'world', 'series', 'of', 'poker']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'find', 'local', 'tournaments', 'near', 'you']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'poker', 'tournaments', 'are', 'played']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'who', 'won', 'the', 'last', 'world', 'series', 'of', 'poker']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'play', 'in', 'online', 'poker', 'tournaments']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'watch', 'a', 'tournament', 'online']
# Filtered Tokens: ['where', 'would', 'you', 'like', 'to', 'find', 'poker', 'tournaments']
# Filtered Tokens: ['which', 'poker', 'tournament', 'are', 'you', 'interested', 'in', 'knowing', 'more', 'about']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'learning', 'how', 'to', 'play', 'poker']
# Filtered Tokens: ['would', 'you', 'like', 'a', 'schedule', 'of', 'poker', 'tournaments']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'world', 'series', 'of', 'poker']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'find', 'local', 'tournaments', 'near', 'you']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'poker', 'tournaments', 'are', 'played']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'who', 'won', 'the', 'last', 'world', 'series', 'of', 'poker']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'play', 'in', 'online', 'poker', 'tournaments']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'watch', 'a', 'tournament', 'online']
# Filtered Tokens: ['where', 'would', 'you', 'like', 'to', 'find', 'poker', 'tournaments']
# Filtered Tokens: ['which', 'poker', 'tournament', 'are', 'you', 'interested', 'in', 'knowing', 'more', 'about']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'learning', 'how', 'to', 'play', 'poker']
# Filtered Tokens: ['would', 'you', 'like', 'a', 'schedule', 'of', 'poker', 'tournaments']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'the', 'world', 'series', 'of', 'poker']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'find', 'local', 'tournaments', 'near', 'you']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'poker', 'tournaments', 'are', 'played']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'who', 'won', 'the', 'last', 'world', 'series', 'of', 'poker']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'play', 'in', 'online', 'poker', 'tournaments']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'watch', 'a', 'tournament', 'online']
# Filtered Tokens: ['where', 'would', 'you', 'like', 'to', 'find', 'poker', 'tournaments']
# Filtered Tokens: ['which', 'poker', 'tournament', 'are', 'you', 'interested', 'in', 'knowing', 'more', 'about']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'scooter', 'laws']
# Filtered Tokens: ['there', 'are', 'some', 'cool', 'deals', 'available', 'shall', 'i', 'show', 'them']
# Filtered Tokens: ['will', 'this', 'be', 'for', 'an', 'adult', 'or', 'child']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'explore', 'more', 'on', 'scooters']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'purchase', 'one', 'or', 'rent', 'it']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'locations', 'that', 'have', 'the', 'scooters']
# Filtered Tokens: ['are', 'you', 'looking', 'to', 'buy', 'a', 'scooter']
# Filtered Tokens: ['are', 'you', 'looking', 'to', 'rent', 'a', 'scooter']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'build', 'a', 'scooter']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'change', 'scooter', 'oil']
# Filtered Tokens: ['do', 'you', 'have', 'a', 'specific', 'brand', 'name', 'on', 'your', 'mind']
# Filtered Tokens: ['do', 'you', 'need', 'a', 'retailer', 'near', 'you']
# Filtered Tokens: ['is', 'this', 'for', 'mobility', 'or', 'fun']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'scooter', 'laws']
# Filtered Tokens: ['there', 'are', 'some', 'cool', 'deals', 'available', 'shall', 'i', 'show', 'them']
# Filtered Tokens: ['will', 'this', 'be', 'for', 'an', 'adult', 'or', 'child']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'explore', 'more', 'on', 'scooters']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'purchase', 'one', 'or', 'rent', 'it']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'locations', 'that', 'have', 'the', 'scooters']
# Filtered Tokens: ['are', 'you', 'looking', 'to', 'buy', 'a', 'scooter']
# Filtered Tokens: ['are', 'you', 'looking', 'to', 'rent', 'a', 'scooter']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'build', 'a', 'scooter']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'change', 'scooter', 'oil']
# Filtered Tokens: ['do', 'you', 'have', 'a', 'specific', 'brand', 'name', 'on', 'your', 'mind']
# Filtered Tokens: ['do', 'you', 'need', 'a', 'retailer', 'near', 'you']
# Filtered Tokens: ['is', 'this', 'for', 'mobility', 'or', 'fun']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'scooter', 'laws']
# Filtered Tokens: ['there', 'are', 'some', 'cool', 'deals', 'available', 'shall', 'i', 'show', 'them']
# Filtered Tokens: ['will', 'this', 'be', 'for', 'an', 'adult', 'or', 'child']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'explore', 'more', 'on', 'scooters']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'purchase', 'one', 'or', 'rent', 'it']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'locations', 'that', 'have', 'the', 'scooters']
# Filtered Tokens: ['are', 'you', 'looking', 'to', 'buy', 'a', 'scooter']
# Filtered Tokens: ['are', 'you', 'looking', 'to', 'rent', 'a', 'scooter']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'build', 'a', 'scooter']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'change', 'scooter', 'oil']
# Filtered Tokens: ['do', 'you', 'have', 'a', 'specific', 'brand', 'name', 'on', 'your', 'mind']
# Filtered Tokens: ['do', 'you', 'need', 'a', 'retailer', 'near', 'you']
# Filtered Tokens: ['is', 'this', 'for', 'mobility', 'or', 'fun']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'scooter', 'laws']
# Filtered Tokens: ['there', 'are', 'some', 'cool', 'deals', 'available', 'shall', 'i', 'show', 'them']
# Filtered Tokens: ['will', 'this', 'be', 'for', 'an', 'adult', 'or', 'child']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'explore', 'more', 'on', 'scooters']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'purchase', 'one', 'or', 'rent', 'it']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'locations', 'that', 'have', 'the', 'scooters']
# Filtered Tokens: ['are', 'you', 'looking', 'to', 'buy', 'a', 'scooter']
# Filtered Tokens: ['are', 'you', 'looking', 'to', 'rent', 'a', 'scooter']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'build', 'a', 'scooter']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'change', 'scooter', 'oil']
# Filtered Tokens: ['do', 'you', 'have', 'a', 'specific', 'brand', 'name', 'on', 'your', 'mind']
# Filtered Tokens: ['do', 'you', 'need', 'a', 'retailer', 'near', 'you']
# Filtered Tokens: ['is', 'this', 'for', 'mobility', 'or', 'fun']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'ron', 'howards', 'life', 'story', 'and', 'career', 'highlights']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'old', 'ron', 'howard', 'is']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'ron', 'howards', 'directing', 'career']
# Filtered Tokens: ['what', 'would', 'you', 'like', 'to', 'know', 'about', 'his', 'family']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'how', 'many', 'movies', 'ron', 'howard', 'has', 'directed']
# Filtered Tokens: ['would', 'you', 'want', 'to', 'know', 'about', 'ron', 'howards', 'acting', 'career']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'ron', 'howards', 'personal', 'life']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'when', 'ron', 'howard', 'was', 'younger', 'or', 'his', 'older', 'work']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'list', 'of', 'movies', 'ron', 'howard', 'directed']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'ron', 'howard', 'biographies']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'upcoming', 'movies', 'by', 'ron', 'howard']
# Filtered Tokens: ['are', 'you', 'tring', 'to', 'find', 'movies', 'and', 'tv', 'shows', 'where', 'ron', 'howard', 'was', 'an', 'actor']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'compare', 'different', 'ron', 'howard', 'movies']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'find', 'films', 'that', 'ron', 'howard', 'directed']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'ron', 'howards', 'life', 'story', 'and', 'career', 'highlights']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'old', 'ron', 'howard', 'is']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'ron', 'howards', 'directing', 'career']
# Filtered Tokens: ['what', 'would', 'you', 'like', 'to', 'know', 'about', 'his', 'family']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'how', 'many', 'movies', 'ron', 'howard', 'has', 'directed']
# Filtered Tokens: ['would', 'you', 'want', 'to', 'know', 'about', 'ron', 'howards', 'acting', 'career']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'ron', 'howards', 'personal', 'life']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'when', 'ron', 'howard', 'was', 'younger', 'or', 'his', 'older', 'work']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'list', 'of', 'movies', 'ron', 'howard', 'directed']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'ron', 'howard', 'biographies']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'upcoming', 'movies', 'by', 'ron', 'howard']
# Filtered Tokens: ['are', 'you', 'tring', 'to', 'find', 'movies', 'and', 'tv', 'shows', 'where', 'ron', 'howard', 'was', 'an', 'actor']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'compare', 'different', 'ron', 'howard', 'movies']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'find', 'films', 'that', 'ron', 'howard', 'directed']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'ron', 'howards', 'life', 'story', 'and', 'career', 'highlights']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'old', 'ron', 'howard', 'is']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'ron', 'howards', 'directing', 'career']
# Filtered Tokens: ['what', 'would', 'you', 'like', 'to', 'know', 'about', 'his', 'family']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'how', 'many', 'movies', 'ron', 'howard', 'has', 'directed']
# Filtered Tokens: ['would', 'you', 'want', 'to', 'know', 'about', 'ron', 'howards', 'acting', 'career']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'ron', 'howards', 'personal', 'life']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'when', 'ron', 'howard', 'was', 'younger', 'or', 'his', 'older', 'work']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'a', 'list', 'of', 'movies', 'ron', 'howard', 'directed']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'ron', 'howard', 'biographies']
# Filtered Tokens: ['are', 'you', 'looking', 'for', 'upcoming', 'movies', 'by', 'ron', 'howard']
# Filtered Tokens: ['are', 'you', 'tring', 'to', 'find', 'movies', 'and', 'tv', 'shows', 'where', 'ron', 'howard', 'was', 'an', 'actor']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'compare', 'different', 'ron', 'howard', 'movies']
# Filtered Tokens: ['are', 'you', 'trying', 'to', 'find', 'films', 'that', 'ron', 'howard', 'directed']
# Filtered Tokens: ['are', 'you', 'interested', 'in', 'ron', 'howards', 'life', 'story', 'and', 'career', 'highlights']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'how', 'old', 'ron', 'howard', 'is']
# Filtered Tokens: ['do', 'you', 'want', 'to', 'know', 'more', 'about', 'ron', 'howards', 'directing', 'career']
# Filtered Tokens: ['what', 'would', 'you', 'like', 'to', 'know', 'about', 'his', 'family']
# Filtered Tokens: ['would', 'you', 'like', 'to', 'know', 'how', 'many', 'movies', 'ron', 'howard', 'has', 'directed']
